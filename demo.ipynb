# %%
from inspect_ai.analysis.beta import evals_df
from inspect_viz import Data

evals = Data.from_dataframe(evals_df("."))

# %%
from inspect_viz.table import table, column

table(
    data=evals, 
    columns=[
        column("model", label="Model"), 
        column("task_name", label="Task"), 
        column("score_headline_metric", label="Metric"),
        column("score_headline_value", label="Value")
    ]
)
# Out:
# Component(spec='{"input":"table","from":"ZsZjRtVScU6G4vRWo3j7gy","filter_by":"$selection_ZsZjRtVScU6G4vRWo3j7g…
